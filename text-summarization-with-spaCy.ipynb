# %% [markdown]
# # Text Summarization with spaCy

# %% [markdown]
# Spacy is a Python library that provides various natural language processing (NLP) capabilities, including text summarization.
#
# Text summarization involves condensing a longer piece of text into a shorter summary, while retaining the most important information.
#
# Spacy's summarization capabilities rely on machine learning algorithms that identify the most important sentences in a text and use them to generate a summary.
#
# Spacy's summarization capabilities can be customized by adjusting various parameters, such as the length of the summary and the importance assigned to different types of words and phrases.
#
# Text summarization with Spacy can be used in a variety of applications, such as news articles, legal documents, and academic papers, to quickly and efficiently distill important information from longer texts.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# Load CSV file into DataFrame
df = pd.read_csv('output-merge.csv')
df = df[['Title', 'Content','Category','SubCategory']]
df
# Out:
#                                                   Title  \
# 0     \n      Consumer confidence worsened in April ...
# 1     \n      GM earnings much better than expected ...
# 2     \n      Chevrolet Bolt, GM’s first popular ele...
# 3     \n      New home sales rise for the fourth mon...
# 4          \n      Tucker Carlson out at Fox News\n
# ...                                                 ...
# 1180  Hospitals and health care facilities should dr...
# 1181  ChatGPT for health care providers: Can the AI ...
# 1182  Want to get better sleep? Exercise for this lo...
# 1183  Massachusetts town says Avian Flu detected amo...
# 1184  The world lost faith in childhood vaccines dur...
#
#                                                 Content        Category  \
# 0     US consumer confidence worsened in April as Am...           MONEY
# 1     General Motors reported a much better-than-exp...        BUSINESS
# 2     The Chevrolet Bolt EV, General Motors first fu...        BUSINESS
# 3     New home sales rose in March, climbing for the...        BUSINESS
# 4     Fox News and Tucker Carlson, the right-wing ex...   ENTERTAINMENT
# ...                                                 ...             ...
# 1180  Walensky told Congress that masking guidance ‘...  HEALTHY LIVING
# 1181  OpenAI CEO Sam Altman said that he was "a litt...  HEALTHY LIVING
# 1182  Get the rest you need with these simple tweaks...  HEALTHY LIVING
# 1183  Fox News Flash top headlines are here. Check o...  HEALTHY LIVING
# 1184  Fox News Flash top headlines are here. Check o...  HEALTHY LIVING
#
#      SubCategory
# 0        economy
# 1       business
# 2       business
# 3          homes
# 4            NaN
# ...          ...
# 1180      health
# 1181      health
# 1182      health
# 1183      health
# 1184      health
#
# [1185 rows x 4 columns]

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from collections import Counter
from heapq import nlargest
spacy.cli.download("en_core_web_md")
from string import punctuation
punctuation=punctuation+ '\n'
# Out:
# Collecting en_core_web_md==2.3.1
#   Using cached en_core_web_md-2.3.1-py3-none-any.whl
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from en_core_web_md==2.3.1) (2.3.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.28.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (3.0.8)
# Requirement already satisfied: setuptools in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (63.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (0.10.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.24.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (0.7.9)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.0.2)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (7.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (1.26.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/keerthanaakannan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_md==2.3.1) (2.0.4)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
import nltk

# Download the stopwords corpus (only need to do this once)
nltk.download('stopwords')

# Load the stopwords into a set
stopwords = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/keerthanaakannan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nlp = spacy.load('en_core_web_md')

# %% [markdown]
# Another way of doing it by defining a function called textSummarizer()

# %%
def textSummarizer(text, percentage):
    
    # load the model into spaCy
#     nlp = spacy.load('en_core_web_sm')
    
    # pass the text into the nlp function
    doc= nlp(text)
    
    ## The score of each word is kept in a frequency table
    tokens=[token.text for token in doc]
    freq_of_word=dict()
    
    # Text cleaning and vectorization 
    for word in doc:
        if word.text.lower() not in list(STOP_WORDS):
            if word.text.lower() not in punctuation:
                if word.text not in freq_of_word.keys():
                    freq_of_word[word.text] = 1
                else:
                    freq_of_word[word.text] += 1
                    
    # Maximum frequency of word
    max_freq=max(freq_of_word.values())
    
    # Normalization of word frequency
    for word in freq_of_word.keys():
        freq_of_word[word]=freq_of_word[word]/max_freq
        
    # In this part, each sentence is weighed based on how often it contains the token.
    sent_tokens= [sent for sent in doc.sents]
    sent_scores = dict()
    for sent in sent_tokens:
        for word in sent:
            if word.text.lower() in freq_of_word.keys():
                if sent not in sent_scores.keys():                            
                    sent_scores[sent]=freq_of_word[word.text.lower()]
                else:
                    sent_scores[sent]+=freq_of_word[word.text.lower()]
    
    
    len_tokens=int(len(sent_tokens)*percentage)
    
    # Summary for the sentences with maximum score. Here, each sentence in the list is of spacy.span type
    summary = nlargest(n = len_tokens, iterable = sent_scores,key=sent_scores.get)
    
    # Prepare for final summary
    final_summary=[word.text for word in summary]
    
    #convert to a string
    summary=" ".join(final_summary)
    
    # Return final summary
    return summary

# %% [markdown]
# ## Summarising for each news article

# %%
df['Summary'] = df['Content'].apply(lambda x: textSummarizer(x,0.3))

# %%
df.to_excel('summary.xlsx')

# %% [markdown]
# # Summary for each category of news article

# %%
# Apply textSummarizer function to 'Content' column
# df['Summary'] = df['Content'].apply(lambda x: textSummarizer(x,0.3))
# df
df['Summary'] = df['Content'].astype(str).apply(lambda x: textSummarizer(x, 0.1))

# %%
def tclean(title):
    
    title = title.replace("\n", "").strip()
    return title
df['Title'] = df['Title'].apply(tclean)

# %%
df[['Category','SubCategory','Title','Summary']]
# Out:
#             Category SubCategory  \
# 0              MONEY     economy
# 1           BUSINESS    business
# 2           BUSINESS    business
# 3           BUSINESS       homes
# 4      ENTERTAINMENT         NaN
# ...              ...         ...
# 1180  HEALTHY LIVING      health
# 1181  HEALTHY LIVING      health
# 1182  HEALTHY LIVING      health
# 1183  HEALTHY LIVING      health
# 1184  HEALTHY LIVING      health
#
#                                                   Title  \
# 0     Consumer confidence worsened in April as Ameri...
# 1     GM earnings much better than expected as reven...
# 2     Chevrolet Bolt, GM’s first popular electric ve...
# 3     New home sales rise for the fourth month in a row
# 4                        Tucker Carlson out at Fox News
# ...                                                 ...
# 1180  Hospitals and health care facilities should dr...
# 1181  ChatGPT for health care providers: Can the AI ...
# 1182  Want to get better sleep? Exercise for this lo...
# 1183  Massachusetts town says Avian Flu detected amo...
# 1184  The world lost faith in childhood vaccines dur...
#
#                                                 Summary
# 0     The business group’s measure of economic expec...
# 1     It also said it now expects to earnings betwee...
# 2     The Michigan assembly plant where it’s produce...
# 3     New home sales rose in March, climbing for the...
# 4     Jonathan Greenblatt, the head of the Anti-Defa...
# ...                                                 ...
# 1180  "After three years of universal masking in hea...
# 1181  " This might mean making up diseases the patie...
# 1182  TEXAS HOSPITAL SEES 30 INFANT DEATHS IN 15-MON...
# 1183  The town of Swansea, 50 miles south of Boston,...
# 1184  NEARLY 13 MILLION AFRICAN CHILDREN MISSED VACC...
#
# [1185 rows x 4 columns]

# %%
grouped_df = df.groupby(['Category','SubCategory','Title','Summary']).count()
grouped_df
filtered = grouped_df.loc[('WORLD NEWS','europe')]
filtered
# Out:
#                                                                                                        Content
# Title                                              Summary
# Analysis: Will Italy’s PM stop the boats or wil... “This is a serious issue, I think this is the m...        1
# Cocaine worth nearly $440 million found floatin...                                                           1
# Fleet of Russian spy ships has been gathering i... “We saw a couple of months ago that Russian shi...        1
# Foreign powers rescue nationals while Sudanese ... One British citizen, named Fatima, told the BBC...        1
# Italian minister sparks fury for saying immigra... Far right White supremacist groups and conserva...        1
# NATO chief says Ukraine’s ‘rightful place’ is i... In his first visit to Ukraine since the invasio...        1
# One of the last survivors of the Warsaw Ghetto ... “She knew that if I stayed I would not survive ...        1
# Poland and Hungary ban Ukrainian grain amid glu... Hungarian Agriculture Minister István Nagy on S...        1
# Russia having difficulty making new weapons, bu... “Moscow is estimated to have lost anywhere from...        1
# Russia’s Lavrov hosts UN meeting on ‘internatio... “As was the case during the Cold War, we have r...        2
# Russia’s deputy defense minister is under sanct... “For the uber-corrupt people, it’s almost like ...        2
# Silence along Ukraine’s southern front fuels sp... Just Sunday, the US-based Institute for the Stu...        2
# Some Ukrainians who fled Russia’s war ended up ... It’s critical to recall that their core rights ...        1
# Son of Kremlin spokesman Peskov says he served ... “I considered it my duty… I couldn’t sit on the...        1
# Spain exhumes fascist founder’s body as sympath... A handful of supporters gathered outside the ga...        1
# Two Russians claiming to be former Wagner comma... But Prigozhin said that “if none is confirmed, ...        1
# Two men claiming to be ex-Wagner fighters said ... Prigozhin claimed: “This group collects comprom...        1
# Wall Street Journal reporter Evan Gershkovich d... “Given the way the Russians have treated this m...        1

# %% [markdown]
# <left><img src="images/sudan.gif" width="400" height="300" /></left>
