# %% [markdown]
# # WEB SCRAPING

# %% [markdown]
# <left><img src="images/scrape.gif" width="400" height="300" /></left>

# %%
from urllib.request import Request, urlopen
import html5lib
from bs4 import BeautifulSoup 
import requests
import csv
import pandas as pd

from urllib.parse import urlparse

# %% [markdown]
# <h1><b>CNN MORE SCRAPED DATA</b></h1>

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import pandas as pd
import csv

# Define the topics to search for
topic=['https://www.cnn.com/politics', 'https://www.cnn.com/business', 
         'https://www.cnn.com/health', 'https://www.cnn.com/entertainment',
         'https://www.cnn.com/world', 'https://www.cnn.com/us', 'https://www.cnn.com/us/crime-and-justice', 
         'https://www.cnn.com/world/africa', 'https://www.cnn.com/world/americas', 
         'https://www.cnn.com/world/asia', 'https://www.cnn.com/world/australia', 'https://www.cnn.com/world/china', 
         'https://www.cnn.com/world/europe', 'https://www.cnn.com/opinions', 
         'https://www.cnn.com/world/india']
# Open the CSV file for writing
with open('news-cnn-updated-2.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Title', 'Content', 'Number of Words', 'Category','Date Published','Link'])

    # Set to store processed URLs
    processed_urls = set()

    # Loop over the topics
    for t in topic:
        response = requests.get(t)
        soup = BeautifulSoup(response.text, 'html.parser')

        # desired section for links in the main search page
        #sec = soup.find("div", {"class": "container__headline container_lead-plus-headlines-with-images__headline"})
        urls = []
        # concat_links=[]
        # number of links inside this part
        links = soup.find_all("a", {"class": "container__link container_vertical-strip__link"})
        # container__link container_lead-plus-headlines-with-images__link
        # print(f'Number of links found: {len(links)}')
        # links = sec.select('div a')
        # Loop over the anchor tags and extract the URLs
  # Loop over the anchor tags and extract the URLs
        for link in links:
            href = link.get('href')
            if href.startswith('http'):
                urls.append(href)
            else:
                urls.append('https://www.cnn.com' + href)
            for url in urls:
                if url in processed_urls:
                    continue
                else:
                    processed_urls.add(url)

                keywords = []
                parsed_url = urlparse(url)
                path = parsed_url.path
                date_published = path.split('/')[1:4]
                date_published = '-'.join(date_published)
                keywords_str = path[len(date_published)+1:path.rfind('/')]
                keywords = keywords_str.split('/')
                category = ''
                if len(keywords) > 1:
                    category = ''.join(keywords[1])
                sub_category = ''
                if len(keywords) > 2:
                    sub_category = ''.join(keywords[2])
                    
                # Send a GET request to the URL and extract the article content
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                article = soup.find('div', class_="article__content-container")
                if article is None:
                    continue
                title = soup.find('h1').text
                text = ''
                div_list = article.find_all('p', class_="paragraph inline-placeholder")
                for div in div_list:
                    text += div.text.strip() + ' '
                num_words = len(text.split())

                # Write the row to the CSV file
                writer.writerow([title, text, num_words,category, date_published, url])
                print(sub_category)
# Out:
# veterans-ptsd-psychedelics-wwii-wellness
# urban-foraging-wellness-scn
# nigeria-indomie-noodles-probe-intl
# ancient-dna-pendant-scn
# latinos-cleveland-texas-mass-shooting-reaj
# tou-thao-george-floyd-trial
# california-college-student-stabbing-tuesday
# bob-lee-autopsy-cash-app-founder
# world-cup-security-guard-dies-after-fall-spt-intl
# power-outage-moore-county-criminal-investigation
# sudan-fighting-evacuations-saudi-arabia-intl
# clashes-west-darfur-sudan-food-water-intl-hnk
# sudan-american-teacher-escape-intl-hnk
# jahawi-bertolli-underwater-kenya-c2e-spc-intl
# sudan-fighting-doctors-hospitals-intl
# kenya-second-pastor-arrested-intl
# brazil-lula-ukraine-peace-coalition-intl-latam
# cctv-brazil-riot-intl-latam
# us-biden-amazon-fund-petro-intl-latam
# fbi-arrest-china-police-station-intl-analysis
# mexico-la-palma-swimming-pool-shooting-intl-hnk
# pablo-escobar-cocaine-hippo-dies-intl-scli
# us-south-korea-nuclear-armed-submarine-explainer-intl-hnk-ml
# japan-fukushima-disaster-wastewater-fishing-concerns-hnk-dst-dg-intl
# us-philippines-balikatan-military-exercises-intl-hnk-ml
# jacinda-ardern-harvard-fellowships-intl-hnk
# south-korea-kpop-moonbin-astro-death-intl-hnk
# australia-defense-strategic-review-intl-hnk
# cyclone-ilsa-new-speed-record-australia-intl-hnk
# cyclone-ilsa-western-australia-thursday-intl-hnk
# cyclone-ilsa-western-australia-intl-hnk
# platypus-man-charged-australia-intl-scli
# radioactive-capsule-missing-western-australia-intl
# china-ambassador-lu-shaye-baltic-soviet-states-europe-intl-hnk
# beijing-zero-covid-vigil-protesters-released-intl-hnk
# china-beijing-fire-censorship-intl-hnk
# beijing-hospital-fire-intl
# china-antarctic-station-construction-csis-report-intl-hnk
# china-blogger-sentenced-program-think-intl-mic-hnk
# ukraine-drone-attack-putin-kremlin-intl
# uk-king-charles-coronation-weather-intl
# scotus-justice-ketanji-brown-jackson-opinion
# bridgerton-season-2-anthony-thomas
# kanye-kim-trevor-noah-harassment-filipovic
# wordle-craze-new-york-times-hemmer
# former-indian-lawmaker-killed-intl
# tibetan-leader-defends-dalai-lama-kissing-boy-video-intl-hnk
# dalai-lama-apology-kissing-boy-video-intl-hnk

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import pandas as pd
import csv

# Define the topics to search for
topic=['https://www.cnn.com/politics', 'https://www.cnn.com/business', 
         'https://www.cnn.com/health', 'https://www.cnn.com/entertainment',
         'https://www.cnn.com/world', 'https://www.cnn.com/us', 'https://www.cnn.com/us/crime-and-justice', 
         'https://www.cnn.com/world/africa', 'https://www.cnn.com/world/americas', 
         'https://www.cnn.com/world/asia', 'https://www.cnn.com/world/australia', 'https://www.cnn.com/world/china', 
         'https://www.cnn.com/world/europe', 'https://www.cnn.com/opinions', 
         'https://www.cnn.com/world/india']
# Open the CSV file for writing
with open('news-cnn-updated-2.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Title', 'Content', 'Number of Words', 'Category', 'Date Published','Link'])

    # Set to store processed URLs
    processed_urls = set()

    # Loop over the topics
    for t in topic:
        response = requests.get(t)
        soup = BeautifulSoup(response.text, 'html.parser')

        # desired section for links in the main search page
        #sec = soup.find("div", {"class": "container__headline container_lead-plus-headlines-with-images__headline"})
        urls = []
        # concat_links=[]
        # number of links inside this part
        links = soup.find_all("a", {"class": "container__link container_vertical-strip__link"})
        # container__link container_lead-plus-headlines-with-images__link
        # print(f'Number of links found: {len(links)}')
        # links = sec.select('div a')
        # Loop over the anchor tags and extract the URLs
        for link in links:
            href = link.get('href')
            if href.startswith('http'):
                urls.append(href)
            else:
                urls.append('https://www.cnn.com' + href)
            for url in urls:
                if url in processed_urls:
                    continue
                else:
                    processed_urls.add(url)

                keywords = []
                parsed_url = urlparse(url)
                path = parsed_url.path
                date_published = path.split('/')[1:4]
                date_published = '-'.join(date_published)
                keywords_str = path[len(date_published)+1:path.rfind('/')]
                keywords = keywords_str.split('/')
                category = ''
                if len(keywords) > 1:
                    category = ''.join(keywords[1])
                sub_category = ''
                if len(keywords) > 2:
                    sub_category = ''.join(keywords[2])
                    
                # Send a GET request to the URL and extract the article content
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                article = soup.find('div', class_="article__content-container")
                if article is None:
                    continue
                title = soup.find('h1').text
                text = ''
                div_list = article.find_all('p', class_="paragraph inline-placeholder")
                for div in div_list:
                    text += div.text.strip() + ' '
                num_words = len(text.split())

                # Write the row to the CSV file
                writer.writerow([title, text, num_words,category, date_published, url])
                print(sub_category)
# Out:
# veterans-ptsd-psychedelics-wwii-wellness
# urban-foraging-wellness-scn
# nigeria-indomie-noodles-probe-intl
# ancient-dna-pendant-scn
# latinos-cleveland-texas-mass-shooting-reaj
# tou-thao-george-floyd-trial
# california-college-student-stabbing-tuesday
# bob-lee-autopsy-cash-app-founder
# world-cup-security-guard-dies-after-fall-spt-intl
# power-outage-moore-county-criminal-investigation
# sudan-fighting-evacuations-saudi-arabia-intl
# clashes-west-darfur-sudan-food-water-intl-hnk
# sudan-american-teacher-escape-intl-hnk
# jahawi-bertolli-underwater-kenya-c2e-spc-intl
# sudan-fighting-doctors-hospitals-intl
# kenya-second-pastor-arrested-intl
# brazil-lula-ukraine-peace-coalition-intl-latam
# cctv-brazil-riot-intl-latam
# us-biden-amazon-fund-petro-intl-latam
# fbi-arrest-china-police-station-intl-analysis
# mexico-la-palma-swimming-pool-shooting-intl-hnk
# pablo-escobar-cocaine-hippo-dies-intl-scli
# us-south-korea-nuclear-armed-submarine-explainer-intl-hnk-ml
# japan-fukushima-disaster-wastewater-fishing-concerns-hnk-dst-dg-intl
# us-philippines-balikatan-military-exercises-intl-hnk-ml
# jacinda-ardern-harvard-fellowships-intl-hnk
# south-korea-kpop-moonbin-astro-death-intl-hnk
# australia-defense-strategic-review-intl-hnk
# cyclone-ilsa-new-speed-record-australia-intl-hnk
# cyclone-ilsa-western-australia-thursday-intl-hnk
# cyclone-ilsa-western-australia-intl-hnk
# platypus-man-charged-australia-intl-scli
# radioactive-capsule-missing-western-australia-intl
# china-ambassador-lu-shaye-baltic-soviet-states-europe-intl-hnk
# beijing-zero-covid-vigil-protesters-released-intl-hnk
# china-beijing-fire-censorship-intl-hnk
# beijing-hospital-fire-intl
# china-antarctic-station-construction-csis-report-intl-hnk
# china-blogger-sentenced-program-think-intl-mic-hnk
# ukraine-drone-attack-putin-kremlin-intl
# uk-king-charles-coronation-weather-intl
# scotus-justice-ketanji-brown-jackson-opinion
# bridgerton-season-2-anthony-thomas
# kanye-kim-trevor-noah-harassment-filipovic
# wordle-craze-new-york-times-hemmer
# former-indian-lawmaker-killed-intl
# tibetan-leader-defends-dalai-lama-kissing-boy-video-intl-hnk
# dalai-lama-apology-kissing-boy-video-intl-hnk

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import pandas as pd
import csv

# Define the topics to search for
topic=['https://www.cnn.com/politics', 'https://www.cnn.com/business', 
         'https://www.cnn.com/health', 'https://www.cnn.com/entertainment',
         'https://www.cnn.com/world', 'https://www.cnn.com/us', 'https://www.cnn.com/us/crime-and-justice', 
         'https://www.cnn.com/world/africa', 'https://www.cnn.com/world/americas', 
         'https://www.cnn.com/world/asia', 'https://www.cnn.com/world/australia', 'https://www.cnn.com/world/china', 
         'https://www.cnn.com/world/europe', 'https://www.cnn.com/opinions', 
         'https://www.cnn.com/world/india', 'https://www.cnn.com/world/middle-east', 
         'https://www.cnn.com/world/united-kingdom', 'https://www.cnn.com/politics/joe-biden', 
         'https://www.cnn.com/business/tech', 
         'https://www.cnn.com/business/media', 'https://www.cnn.com/business/success',
         'https://www.cnn.com/entertainment/movies', 'https://www.cnn.com/entertainment/tv-shows', 
         'https://www.cnn.com/entertainment/celebrities',
         'https://www.cnn.com/sport', 'https://www.cnn.com/sport/football', 'https://www.cnn.com/sport/tennis',
         'https://www.cnn.com/sport/golf', 'https://www.cnn.com/sport/motorsport', 'https://www.cnn.com/sport/us-sports',
         'https://www.cnn.com/sport/milan-cortina-winter-olympics-2026', 'https://www.cnn.com/sport/climbing']
# Open the CSV file for writing
with open('news-cnn-updated.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Title', 'Content', 'Number of Words', 'Category', 'Date Published','Link'])

    # Set to store processed URLs
    processed_urls = set()

    # Loop over the topics
    for t in topic:
        response = requests.get(t)
        soup = BeautifulSoup(response.text, 'html.parser')

        # desired section for links in the main search page
        #sec = soup.find("div", {"class": "container__headline container_lead-plus-headlines-with-images__headline"})
        urls = []
        # concat_links=[]
        # number of links inside this part
        links = soup.find_all("a", {"class": "container__link container_lead-plus-headlines-with-images__link"})
         
        # print(f'Number of links found: {len(links)}')
        # links = sec.select('div a')
        # Loop over the anchor tags and extract the URLs
        for link in links:
            href = link.get('href')
            if href.startswith('http'):
                urls.append(href)
            else:
                urls.append('https://www.cnn.com' + href)

        # Loop over the URLs and extract the articles
        for url in urls:
                if url in processed_urls:
                    continue
                else:
                    processed_urls.add(url)

                keywords = []
                parsed_url = urlparse(url)
                path = parsed_url.path
                date_published = path.split('/')[1:4]
                date_published = '-'.join(date_published)
                keywords_str = path[len(date_published)+1:path.rfind('/')]
                keywords = keywords_str.split('/')
                category = ''
                if len(keywords) > 1:
                    category = ''.join(keywords[1])
                sub_category = ''
                if len(keywords) > 2:
                    sub_category = ''.join(keywords[2])
                    
                # Send a GET request to the URL and extract the article content
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                article = soup.find('div', class_="article__content-container")
                if article is None:
                    continue
                title = soup.find('h1').text
                text = ''
                div_list = article.find_all('p', class_="paragraph inline-placeholder")
                for div in div_list:
                    text += div.text.strip() + ' '
                num_words = len(text.split())

                # Write the row to the CSV file
                writer.writerow([title, text, num_words,category, date_published, url])
                print(title)
# Out:
#       ‘This May Day is crazy’: China’s holiday spending exceeds pre-pandemic levels for the first time
#
#
#       Nearly half of Americans are nervous about their money in the bank, Gallup survey finds
#
#
#       PacWest Bank says considering ‘all options’ after its shares plunge more than 50%
#
#
#       Washington is letting Chinese airlines increase flights to America
#
#
#       Microsoft opens up its AI-powered Bing to all users
#
#
#       No end in sight for the writers strike as talks break off and both sides brace for long standoff
#
#
#       Takeaways from the Federal Reserve meeting
#
#
#       Police detail the hourslong manhunt that ended in the Atlanta shooting suspect’s arrest
#
#
#       3 suspected of killing Colorado woman by hurling a large rock at her car are charged with first-degree murder
#
#
#       Oklahoma sex offender fatally shot his wife, her 3 kids and 2 teen girls before killing himself, police say
#
#
#       University of California students in Davis fearful and rattled as 3 stabbings in 5 days remain unsolved
#
#
#       JP Morgan CEO Jamie Dimon to be deposed in lawsuits over former client Epstein
#
#
#       Texas massacre suspect charged with 5 counts of murder as investigators say his longtime partner gave him food and clothes while on the run
#
#
#       Nigeria probes popular Indomie noodles after recalls by Malaysia, Taiwan
#
#
#       Floods in western Rwanda kill at least 127 people
#
#
#       Universal Studio Group’s UCP teams up with Nigeria’s Comic Republic in new TV series deal
#
#
#       Leaders of Sudan’s warring factions agree to seven-day ceasefire, South Sudan says
#
#
#       Religious leader linked to Kenya starvation case to face ‘possible terrorism charges’
#
#
#       Uganda lawmakers amend controversial anti-gay law but death penalty for HIV positive sex remains
#
#
#       ‘We can’t get to your passport:’ People stranded in Sudan after Western diplomats flee without returning travel documents
#
#
#       Thousands are trying to escape from Port Sudan. Only a few can make it
#
#
#       Ecuador is in trouble and its president may pay the price
#
#
#       Canadian man charged with aiding suicide by selling lethal substance online
#
#
#       Brazilian police raid former President Bolsonaro’s home, arrest former aide: CNN Brasil
#
#
#       Venezuela’s Juan Guaidó seeks support in Washington after causing a stir in Colombia
#
#
#       Cuba fuel shortages spark fistfights, queues and holiday cutbacks
#
#
#       Human remains found inside crocodile in Australia believed to belong to missing fisherman
#
#
#       Australia to ban recreational vaping in major crackdown on e-cigarettes as teen use soars
#
#
#       ‘MasterChef Australia’ judge Jock Zonfrillo dies on eve of new series, age 46
#
#
#       Australian police sift through 3,000 tons of trash for missing woman’s remains
#
#
#       US Coast Guard suspends search for missing cruise passenger
#
#
#       Wuhan citizen journalist who documented Covid outbreak released after three years detained
#
#
#       With Zelensky call, Xi Jinping steps up bid to broker peace – but does he have a plan?
#
#
#       ‘Bring Ya Ya home’: How a panda in the US turbocharged Chinese nationalist sentiment
#
#
#       China detains Taiwan-based man who published books critical of Communist Party
#
#
#       Taiwan activist formally arrested for suspected ‘secession’ in China
#
#
#       Ukrainian air defenses repelled most intense attack on Kyiv this year, military says
#
#
#       Serbia in shock after school shooting leaves eight children and a security guard dead
#
#
#       A school shooting has rocked Serbia. Here’s what we know
#
#
#       India’s top female wrestlers are camping on the streets of New Delhi. Here’s why
#
#
#       India says border violations erode ‘entire basis’ of ties with China
#
#
#       Eleven people killed in suspected Maoist militant attack in central India
#
#
#       Israel says killers of British-Israeli mother and daughters shot dead in Nablus
#
#
#       Saudi Arabia wants to be a bigger player in the Middle East — this time with diplomacy
#
#
#       Israel military and Palestinians trade fire following hunger striker’s death
#
#
#       Prominent Palestinian detainee Khader Adnan dies in Israeli prison after 87-day hunger strike
#
#
#       Turkey’s upcoming elections could unseat Erdogan. Here’s everything you need to know
#
#
#       Everything you need to know about King Charles III’s coronation
#
#
#       Parts of a controversial anti-protest law come into force ahead of King Charles’ coronation
#
#
#       Slimmed-down royal family ‘doesn’t sound like a good idea,’ Princess Anne says
#
#
#       Bipartisan Senate majority delivers another rebuke to Biden’s regulatory authority
#
#
#       Blinken says US is ‘engaged with Syria’ in efforts to free missing journalist Austin Tice
#
#
#       Top Republicans demand FBI document they claim describes ‘alleged criminal scheme’ related to Biden
#
#
#       Autoworkers union holding off endorsing Biden
#
#
#       The 10 Senate seats most likely to flip in 2024
#
#
#       FTC says Meta should be barred from monetizing data from younger users
#
#
#       Google rolls out an alternative to the password
#
#
#       Apple and Google are teaming up on a plan to make Bluetooth trackers like AirTags safer
#
#
#       ‘ChatGPT is the new crypto’: Meta warns hackers are exploiting interest in the AI chatbot
#
#
#       Meta shuts down network of fake accounts that ‘signal a shift’ in China-based influence efforts
#
#
#       Why the ‘Godfather of AI’ decided he had to ‘blow the whistle’ on the technology
#
#
#       AI pioneer quits Google to warn about the technology’s ‘dangers’
#
#
#       New York Times dismissed from lawsuit Trump brought over disclosure of his tax documents
#
#
#       Jury briefly deliberates in Ed Sheeran copyright infringement case before ending for the day
#
#
#       Tucker Carlson sent a racist text to a producer: ‘It’s not how white men fight’
#
#
#       Tucker Carlson’s racist text message shouldn’t be surprising: Analysis
#
#
#       Where to get the best returns on your savings when rates are high
#
#
#       Your mortgage and home loans: What to do now that the Fed just raised rates again
#
#
#       What to do with your credit card debt now that the Fed raised rates again
#
#
#       Low employee engagement? Managers can help turn it around with this one habit
#
#
#       Today is Tax Day. Here’s what you need to know if you haven’t filed your return yet — and even if you have
#
#
#       Apple offers 4.15% high-yield savings to its Apple Card holders
#
#
#       Even when women make as much as their husbands, they still do more at home
#
#
#       Still haven’t filed your taxes? Here’s what you need to know
#
#
#       Erling Haaland smashes EPL record with 35th league goal of the season … and there’s still 5 games to go
#
#
#       Lazio wins to delay Napoli’s Serie A title celebrations
#
#
#       Soccer star Cristiano Ronaldo tops Forbes’ highest-paid athlete list for 2023 after Saudi Arabia move
#
#
#       Tragedy chanting: ‘Vile’ soccer songs about deaths fueled by ‘need to hurt’ opposing fans
#
#
#       Lionel Messi suspended by Paris Saint-Germain following unauthorized trip to Saudi Arabia
#
#
#       Ryan Reynolds and Rob McElhenney join Wrexham’s open-top bus parade
#
#
#       FIFA President Gianni Infantino threatens Women’s World Cup broadcast blackout in ‘Big 5’ European countries over media rights offers
#
#
#       African soccer’s governing body condemns fan behavior following death of supporter at Champions League game
#
#
#       Russia’s Daria Kasatkina says it ‘makes a lot of sense’ for Ukrainian tennis players to receive support during grass-court season
#
#
#       Mirra Andreeva celebrated her 16th birthday and another astonishing victory at the Madrid Open
#
#
#       Simona Halep says ‘the stress is huge’ as she battles to return to tennis following positive drug test
#
#
#       Poland’s state-owned airline refuses boarding to Russian tennis player
#
#
#       Wimbledon to cover accommodation costs for Ukrainian tennis players
#       Iga Świątek returns from injury layoff and defeats Zheng Qinwen at Porsche Tennis Grand Prix
#
#
#       Rafael Nadal’s French Open participation in doubt as he struggles to recover from injury
#
#
#       Emma Raducanu beaten in less than an hour by Jelena Ostapenko in Stuttgart
#
#
#       Tony Finau caddies for young sons, just hours after Mexico Open win
#
#
#       Jon Rahm sets new PGA Tour earnings record with four months still to play
#
#
#       Chevron Championship: Lilia Vu channels memory of late Grandfather to clinch first major title
#
#
#       Tiger Woods undergoes ‘successful’ surgery following Masters withdrawal
#
#
#       ‘We know what’s at stake’: Matt Fitzpatrick playing to win his brother a PGA Tour spot at Zurich Classic
#
#
#       How to watch the Chevron Championship live: Start time, channel and other things to know
#
#
#       Matt Fitzpatrick beats Jordan Spieth in playoff to win RBC Heritage
#
#
#       Golf Digest launches a new amateur tournament
#
#
#       Formula Equal: Inside the plans to launch a ‘50% male, 50% female’ F1 team
#
#
#       Sergio Perez cruises to victory at Azerbaijan Grand Prix after Max Verstappen loses time under safety car
#
#
#       Sergio Perez wins sprint race at Azerbaijan Grand Prix as Max Verstappen and George Russell argue on track
#
#
#       Editor ‘relieved of duties’ and publishing house apologizes after German magazine’s fake AI interview with Michael Schumacher
#
#
#       Michael Schumacher’s family planning legal action over fake AI interview
#
#
#       Irish rally driver Craig Breen dies after accident during testing
#
#
#       Max Verstappen wins chaotic Australian Grand Prix as Lewis Hamilton takes second
#
#
#       Lewis Hamilton delighted with ‘dream’ qualifying for Australian Grand Prix
#
#
#       Super Bowl LVII most-watched US telecast ever after updated figures
#
#
#       Los Angeles Lakers take Game 1 of heavyweight series against defending champion Golden State Warriors
#
#
#       Joel Embiid vs Nikola Jokić vs Giannis Antetokounmpo: Who will be crowned the 2023 NBA MVP?
#
#
#       James Harden scores 45 points to lift Joel Embiid-less Philadelphia 76ers past Boston Celtics in Game 1
#
#
#       Kamila Valieva: Figure skater could not have achieved ‘perfection’ while doping, says Vladimir Putin
#
#
#       Olympic champion Chloe Kim is taking a break for her mental health
#
#
#       Winter Paralympics: Ukrainian athletes’ thoughts are with those fighting the invasion back home as they enjoy golden success in Beijing
#
#
#       Opening Ceremony: Call for peace as Ukraine’s presence keenly felt at Winter Paralympics

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import pandas as pd
import csv

# Define the topics to search for
topic=['https://www.cnn.com/politics', 'https://www.cnn.com/business', 
         'https://www.cnn.com/health', 'https://www.cnn.com/entertainment',
         'https://www.cnn.com/world', 'https://www.cnn.com/us', 'https://www.cnn.com/us/crime-and-justice', 
         'https://www.cnn.com/world/africa', 'https://www.cnn.com/world/americas', 
         'https://www.cnn.com/world/asia', 'https://www.cnn.com/world/australia', 'https://www.cnn.com/world/china', 
         'https://www.cnn.com/world/europe', 'https://www.cnn.com/opinions', 
         'https://www.cnn.com/world/india', 'https://www.cnn.com/world/middle-east', 
         'https://www.cnn.com/world/united-kingdom', 'https://www.cnn.com/politics/joe-biden', 
         'https://www.cnn.com/business/tech', 
         'https://www.cnn.com/business/media', 'https://www.cnn.com/business/success',
         'https://www.cnn.com/entertainment/movies', 'https://www.cnn.com/entertainment/tv-shows', 
         'https://www.cnn.com/entertainment/celebrities',
         'https://www.cnn.com/sport', 'https://www.cnn.com/sport/football', 'https://www.cnn.com/sport/tennis',
         'https://www.cnn.com/sport/golf', 'https://www.cnn.com/sport/motorsport', 'https://www.cnn.com/sport/us-sports',
         'https://www.cnn.com/sport/milan-cortina-winter-olympics-2026', 'https://www.cnn.com/sport/climbing']

# Open the CSV file for writing
with open('news-cnn-updated-3.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Title', 'Content', 'Number of Words', 'Category', 'Date Published','Link'])

    # Set to store processed URLs
    processed_urls = set()

    # Loop over the topics
    for t in topic:
        response = requests.get(t)
        soup = BeautifulSoup(response.text, 'html.parser')

        # desired section for links in the main search page
        #sec = soup.find("div", {"class": "container__headline container_lead-plus-headlines-with-images__headline"})
        urls = []
        # concat_links=[]
        # number of links inside this part
        links = soup.find_all("a", {"class": "container__link container_lead-plus-headlines__link"})
         
        # print(f'Number of links found: {len(links)}')
        # links = sec.select('div a')
        # Loop over the anchor tags and extract the URLs
        for link in links:
            href = link.get('href')
            if href.startswith('http'):
                urls.append(href)
            else:
                urls.append('https://www.cnn.com' + href)

        # Loop over the URLs and extract the articles
        for url in urls:
                if url in processed_urls:
                    continue
                else:
                    processed_urls.add(url)

                keywords = []
                parsed_url = urlparse(url)
                path = parsed_url.path
                date_published = path.split('/')[1:4]
                date_published = '-'.join(date_published)
                keywords_str = path[len(date_published)+1:path.rfind('/')]
                keywords = keywords_str.split('/')
                category = ''
                if len(keywords) > 1:
                    category = ''.join(keywords[1])
                sub_category = ''
                if len(keywords) > 2:
                    sub_category = ''.join(keywords[2])
                    
                # Send a GET request to the URL and extract the article content
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                article = soup.find('div', class_="article__content-container")
                if article is None:
                    continue
                title = soup.find('h1').text
                text = ''
                div_list = article.find_all('p', class_="paragraph inline-placeholder")
                for div in div_list:
                    text += div.text.strip() + ' '
                num_words = len(text.split())

                # Write the row to the CSV file
                writer.writerow([title, text, num_words,category, date_published, url])
                print(category,sub_category)
# Out:
# politics maralago-footage-trump-special-counsel-calamari
# politics iowa-child-labor-bill-passes
# politics navy-commander-removed-seals
# politics senate-vote-biden-veto-solar-panels
# politics florida-republicans-election-restrictions
# politics trump-defense-e-jean-carroll-lawsuit
# politics maryland-abortion-gender-affirming-care-bills
# politics jill-biden-sotomayor-bronx-childrens-museum
# politics austin-tice-blinken
# politics mass-shooting-reality-america
# politics san-francisco-crime-rate-what-matters
# politics biden-trump-feinstein-age
# politics title-42-border-what-matters
         'https://www.cnn.com/world/europe', 'https://www.cnn.com/opinions', 
         'https://www.cnn.com/world/india', 'https://www.cnn.com/world/middle-east', 
         'https://www.cnn.com/world/united-kingdom', 'https://www.cnn.com/politics/joe-biden', 
         'https://www.cnn.com/business/tech', 
         'https://www.cnn.com/business/media', 'https://www.cnn.com/business/success',
         'https://www.cnn.com/entertainment/movies', 'https://www.cnn.com/entertainment/tv-shows', 
         'https://www.cnn.com/entertainment/celebrities',
         'https://www.cnn.com/sport', 'https://www.cnn.com/sport/football', 'https://www.cnn.com/sport/tennis',
         'https://www.cnn.com/sport/golf', 'https://www.cnn.com/sport/motorsport', 'https://www.cnn.com/sport/us-sports',
         'https://www.cnn.com/sport/milan-cortina-winter-olympics-2026', 'https://www.cnn.com/sport/climbing']
# Open the CSV file for writing
with open('news-cnn-updated-4.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Title', 'Content', 'Number of Words', 'Category', 'Date Published','Link'])

    # Set to store processed URLs
    processed_urls = set()

    # Loop over the topics
    for t in topic:
        response = requests.get(t)
        soup = BeautifulSoup(response.text, 'html.parser')

        # desired section for links in the main search page
        #sec = soup.find("div", {"class": "container__headline container_lead-plus-headlines-with-images__headline"})
        urls = []
        # concat_links=[]
        # number of links inside this part
        links = soup.find_all("a", {"class": "container__link container_lead-plus-headlines-with-images__link container_lead-plus-headlines-with-images__left container_lead-plus-headlines-with-images__light"})
         
        # print(f'Number of links found: {len(links)}')
        # links = sec.select('div a')
        # Loop over the anchor tags and extract the URLs
        for link in links:
            href = link.get('href')
            if href.startswith('http'):
                urls.append(href)
            else:
                urls.append('https://www.cnn.com' + href)

        # Loop over the URLs and extract the articles
        for url in urls:
                if url in processed_urls:
                    continue
                else:
                    processed_urls.add(url)

                keywords = []
                parsed_url = urlparse(url)
                path = parsed_url.path
                date_published = path.split('/')[1:4]
                date_published = '-'.join(date_published)
                keywords_str = path[len(date_published)+1:path.rfind('/')]
                keywords = keywords_str.split('/')
                category = ''
                if len(keywords) > 1:
                    category = ''.join(keywords[1])
                sub_category = ''
                if len(keywords) > 2:
                    sub_category = ''.join(keywords[2])
                    
                # Send a GET request to the URL and extract the article content
                response = requests.get(url)
                soup = BeautifulSoup(response.content, 'html.parser')
                article = soup.find('div', class_="article__content-container")
                if article is None:
                    continue
                title = soup.find('h1').text
                text = ''
                div_list = article.find_all('p', class_="paragraph inline-placeholder")
                for div in div_list:
                    text += div.text.strip() + ' '
                num_words = len(text.split())

                # Write the row to the CSV file
                writer.writerow([title, text, num_words,category, date_published, url])
                print(sub_category)
# Out:
# fed-powell-explainer
# alzheimers-drug-donanemab-eli-lilly
# florida-abortion-term-pregnancy
# murthy-loneliness-isolation
# breast-density-cancer-study
# nurses-unhappy-survey
# emtala-hospital-investigation
# free-covid-tests-phe-wellness
# jamie-foxx-thanks-followers-medical-complication
# dune-part-2-trailer
# rock-hall-fame-inductees
# dancing-with-the-stars-abc
# gwyneth-paltrow-brad-pitt-ben-affleck
# jon-bon-jovi-son-engagement
# kevin-costner-divorce
# kimmel-colbert-repeats-writers-strike
# orlando-bloom-moulin-rouge-audition
# harry-potter-game-of-thrones-max
# barbie-teaser-trailer
# john-wick-keanu-reeves
# stephen-twitch-boss-allison-holker-earnings
# jennifer-garner-return-plc
# greys-anatomy-star-kelly-mccreary-exits-show
# jane-krakowski-show-dance-schmicago
# yellowstone-couple-romance-dating
# kate-hudson-oliver-hudson-sibling-revelry
# nicholas-hoult-interview-renfield-nicolas-cage-dracula-cst-intl
# ryan-seacrest-leaving-live
# jason-sudeikis-twitter-dms-tapper-interview
# erling-haaland-premier-league-record-intl-hnk
# lazio-sassuolo-napoli-serie-a-spt-intl
# churchill-downs-kentucky-derby-horse-deaths-spt-inl
# tori-bowie-death-track-and-field-spt-intl
# the-match-patrick-mahomes-travis-kelce-stephen-curry-klay-thompson-spt-intl
# super-bowl-lvii-most-watched-us-telecast-ever-spt-intl
# mikaela-shiffrin-lindsey-vonn-world-record-spt-intl
# project-shakthi-virgin-peak-nasa-everest-spt-intl
#
# sam-baker-kid-climbing-el-capitan-saturday-trnd

# %% [markdown]
# <h1><b>BBC</b></h1>

# %%
# Define the topics to search for
topic = [
    'https://www.bbc.com/news/world',
    'https://www.bbc.com/news/business',
    'https://www.bbc.com/news/politics',
    'https://www.bbc.com/news/health',
    'https://www.bbc.com/news/education',
    'https://www.bbc.com/news/science_and_environment',
    'https://www.bbc.com/news/technology',
    'https://www.bbc.com/news/entertainment_and_arts',
    'https://www.bbc.com/news/world-60525350',
    'https://www.bbc.com/news/stories',
    # 'https://www.bbc.com/news/in_pictures',
    'https://www.bbc.com/news/world/asia',
    'https://www.bbc.com/sport'
]
processed_urls=set()
# Open the CSV file for writing
with open('bbc-latest-news-section.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Title', 'Content', 'Number of Words', 'Category', 'Date Published','Link'])

    # Loop over the topics
    for t in topic:
            response = requests.get(t)
            soup = BeautifulSoup(response.text, 'html.parser')
            # Extract all the text from the webpage
            # Define the URL and the preferred keyword

            # Find the links
            links = soup.find_all('a', class_="qa-heading-link lx-stream-post__header-link")

            # Loop over the links and extract the articles
            for link in links:
                href = link.get('href')
                if href in processed_urls:
                # Skip already visited URLs
                    continue
                processed_urls.add(href)
                #print(len(processed_urls))
                keywords = []
                parsed_url = urlparse(href)
                path = parsed_url.path
                keyword = path.split("/")[-1].split("-")[:2]
                category = ''
                if len(keyword) > 1:
                    category = ''.join(keyword[0])
                sub_category = ''
                if len(keyword) > 2:
                    sub_category = ''.join(keyword[1:])
                    
                # Create a pandas DataFrame with the URLs and keywords
                data = {
                "keyword": keywords,
                }
                df = pd.DataFrame(data)

                # Save the DataFrame to a CSV file
                df.to_csv("output.csv", index=False)

                if not href.startswith('http'):
                    href = 'https://www.bbc.com' + href

                # Get the article content
                response = requests.get(href)
                soup = BeautifulSoup(response.content, 'html.parser')

                # Find the article title and text
                title = soup.find('h1').text
                div_list = soup.find_all('div', class_='ssrcss-11r1m41-RichTextComponentWrapper ep2nwvo0')
                # div_list = soup.find_all('', class_='paragraph inline-placeholder')
                text = ' '
                for div in div_list:
                    #text += div.text.strip() + ' '
                    # print(statement
                    # Loop through all the p elements and get their text
                    for p in div.find_all('p'):
                        text += p.text.strip() + ' '
                        num_words = len(text.split())
                   
                    
                    date_published = soup.find('time', {'data-testid': 'timestamp'})['datetime']

                # Write the row to the CSV file
                writer.writerow([title,text, num_words,category, date_published, href])

# %%
# Define the topics to search for
topic = [
    'https://www.bbc.com/news/world',
    'https://www.bbc.com/news/business',
    'https://www.bbc.com/news/politics',
    'https://www.bbc.com/news/health',
    'https://www.bbc.com/news/education',
    'https://www.bbc.com/news/science_and_environment',
    'https://www.bbc.com/news/technology',
    'https://www.bbc.com/news/entertainment_and_arts',
    'https://www.bbc.com/news/world-60525350',
    'https://www.bbc.com/news/stories',
    # 'https://www.bbc.com/news/in_pictures',
    'https://www.bbc.com/news/world/asia',
    'https://www.bbc.com/sport'
]
# Open the CSV file for writing
visited_urls = set()
with open('all-news.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Title', 'Content', 'Number of Words', 'Category', 'Date Published','Link'])

    # Loop over the topics
    for t in topic:
            response = requests.get(t)
            soup = BeautifulSoup(response.text, 'html.parser')
            # Extract all the text from the webpage
            # Define the URL and the preferred keyword

            # Find the links
            links = soup.find_all('a', class_="gs-c-promo-heading gs-o-faux-block-link__overlay-link gel-pica-bold nw-o-link-split__anchor")
            
            # Loop over the links and extract the articles
            for link in links:
                href = link.get('href')
                if href in processed_urls:
                # Skip already visited URLs
                    continue
                processed_urls.add(href)
                #print(len(processed_urls))
                keywords = []
                parsed_url = urlparse(href)
                path = parsed_url.path
                keyword = path.split("/")[-1].split("-")[:2]
                category = ''
                if len(keyword) > 1:
                    category = ''.join(keyword[0])
                sub_category = ''
                if len(keyword) > 2:
                    sub_category = ''.join(keyword[1:])
                #category=soup.find_all('aria-label')
                # Create a pandas DataFrame with the URLs and keywords
                data = {
                "keyword": keywords,
                }
                df = pd.DataFrame(data)

                # Save the DataFrame to a CSV file
                df.to_csv("output.csv", index=False)

                if not href.startswith('http'):
                    href = 'https://www.bbc.com' + href

                # Get the article content
                response = requests.get(href)
                soup = BeautifulSoup(response.content, 'html.parser')

                # Find the article title and text
                title = soup.find('h1').text
                div_list = soup.find_all('div', class_='ssrcss-11r1m41-RichTextComponentWrapper ep2nwvo0')
                # div_list = soup.find_all('', class_='paragraph inline-placeholder')
                text = ' '
                for div in div_list:
                    #text += div.text.strip() + ' '
                    # print(statement
                    # Loop through all the p elements and get their text
                    for p in div.find_all('p'):
                        text += p.text.strip() + ' '
                        num_words = len(text.split())
                    # Check if the content is empty, skip storing the record if it is
                    
                    
                    date_published = soup.find('time', {'data-testid': 'timestamp'})['datetime']

                # Write the row to the CSV file
                writer.writerow([title,text, num_words,category, date_published, href])

# %% [markdown]
# # Fox news

# %%
# Define the topics to search for
topic=['https://www.foxnews.com/category/us/true-crime', 'https://www.foxnews.com/us', 'https://www.foxnews.com/politics',
      'https://www.foxnews.com/world', 'https://www.foxnews.com/media', 'https://www.foxnews.com/entertainment',
      'https://www.foxnews.com/sports', 'https://www.foxnews.com/lifestyle', 'https://www.foxbusiness.com',
      'https://www.foxnews.com/science', 'https://www.foxnews.com/health']
# Open the CSV file for writing
with open('fox-news-1.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Title', 'Content', 'Number of Words', 'Category'])

    # Loop over the topics
    for t in topic:
        response = requests.get(t)
        soup = BeautifulSoup(response.text, 'html.parser')

        # desired section for links in the main search page
        sec = soup.find('main', class_="main-content")
        urls = []
        if sec is None:
            continue
        # number of links inside this part
        links = sec.select('h4.title a, h3.title a')
        # print(f'Number of links found: {len(links)}')

        # Loop over the anchor tags and extract the URLs
        for link in links:
            href = link.get('href')
            if href.startswith('http'):
                urls.append(href)
            elif href.startswith('https://www.foxbusiness.com' + href):
                urls.append(href)
            else:
                urls.append('https://www.foxnews.com' + href)
        print(urls)
        # Loop over the URLs and extract the articles
        for url in urls:
            keywords = []
            parsed_url = urlparse(url)
            path = parsed_url.path
            date_published = path.split('/')[1:4]
            date_published = '-'.join(date_published)
            keyword = path.split("/")[-2]
            keywords.append(path[len(date_published)+1:path.rfind('/')])
            
            # Send a GET request to the URL and extract the article content
            response = requests.get(url)
            soup = BeautifulSoup(response.content, 'html.parser')
            article = soup.find('div', class_="article-body")
            if article is None:
                continue
            title = soup.find('h1').text
            text = ''
            div_list = article.find_all('p')
            for div in div_list:
                text += div.text.strip() + ' '
            num_words = len(text.split())

            # Write the row to the CSV file
            writer.writerow([title, text, num_words, keyword])
# Out:
# ['https://www.foxnews.com/us/connecticut-man-48-years-arranging-attack-killed-stepmother-wounded-father', 'https://www.foxnews.com/us/lori-vallow-threatened-cut-up-bestie-when-friendship-turned-sour', 'https://www.foxnews.com/us/florida-prosecutors-seek-death-penalty-jared-bridegan-murder', 'https://www.foxnews.com/world/missing-madeleine-mccanns-parents-await-breakthrough-toddlers-kidnapping', 'https://www.foxnews.com/us/woman-raped-by-oklahoma-killer-as-teen-blasts-his-prison-release', 'https://www.foxnews.com/us/oklahoma-bodies-found-grandmother-3-victims-blasts-convicted-rapist-son-law', 'https://www.foxnews.com/us/cash-app-founder-bob-lee-died-with-drugs-alcohol-system-after-san-francisco-stabbing', 'https://www.foxnews.com/us/new-york-man-accused-killing-cops-daughter-back-streets-prosecutorial-miscommunication', 'https://www.foxnews.com/us/idaho-student-murders-suspect-bryan-kohberger-return-court-month-earlier-than-expected', 'https://www.foxnews.com/us/lori-vallow-trial-cult-moms-hair-duct-tape-wrapped-around-murdered-son-witness-says']

# %%
#df1 = pd.read_csv('news-cnn-updated.csv')
df1 = pd.read_csv('news-cnn-updated-2.csv')
df2 = pd.read_csv('news-cnn-updated.csv')
df3=pd.read_csv('news-cnn-updated-3.csv')
df4=pd.read_csv('news-cnn-updated-4.csv')
df5=pd.read_csv('all-news.csv')
df6=pd.read_csv('bbc-latest-news-section.csv')
df7 = pd.read_csv('fox-news-1.csv')

# %%
df_concatenated = pd.concat([ df2,df1, df3, df4,df5,df6,df7])

# %%
df_concatenated.to_csv('output-merged.csv', index=False)
